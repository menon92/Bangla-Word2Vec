# %%
import os
import time
import random
import collections

import numpy as np
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.0'

# %%
# ট্রেনিং প্যারামিটার 
LEARNING_RATE = 0.1
BATCH_SIZE = 1024
NUM_STEPS = 400000
DISPLAY_STEPS = 10000
EVAL_STEPS = 200000

# এই শব্দগুলো দিয়ে আমরা মডেল ট্রেনিং করার সময় টেস্ট করে দেখব যে মডেল কেমন শিখতেছে
EVAL_WORDS = ['মুনা', 'বকুল', 'বাকের']

# এম্বেডিং ভেক্টরে ডাইমেসন। একটা শব্দের বিপরীতে ২০০ টা স্কেলার ভেলু জমা থাকবে 
# এবং এটাই হবে ওই শব্দের ভেক্টর রিপ্রেজেন্টেসন
EMBEDDING_SIZE = 200

# আমাদের করপাস থেকে এর থেকে বেশি শব্দ থাকলে সেগুলো কে বাদ দেব । 
MAX_VOCABULARY_SIZE = 50000

# যে শব্দগুলো আমাদের ডাটা তে খুব কম সংখ্যক বার আছে সেগুলো আমারা বাদ দিব ।  
MIN_OCCURRENCE = 10

# যখন আমরা ডাটা বানাব তখন আমাদের লেফট এবং রাইট সাইট এর কতগুলো শব্দও ব্যাবহার করব
SKIP_WINDOW = 3

# আমরা একই শব্দ গিয়ে কত গুলো ডাটা বানাতে চাই তার সংখ্যা
NUM_SKIPS = 2

# লস হিসাব করার সময় কতগুলো নেগেটিভ ডাটা ব্যাবহার করতে চাই 
NUM_SAMPLED = 64

# %%
corpus = '/content/kothou_keu_nei_v1.2.txt'

unique_chars = set()
with open(corpus, 'r') as fp:
    lines = fp.readlines()
    # find unique chars so that we can remove unwanted chars
    for line in lines:
        line = line.strip()
        if line:
            for c in line:
                unique_chars.add(c)
    unique_chars = sorted(unique_chars)
    print("Unique chars:", unique_chars)
# Out:
# Unique chars: [' ', '!', '(', ')', ',', '-', '.', '1', ':', ';', '<', '?', 'R', 'r', '{', '·', 'я', 'अ', 'छ', 'ब', 'भ', 'य', 'र', 'ल', 'श', 'ा', 'ि', '्', '।', 'ঁ', 'ং', 'ঃ', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'এ', 'ঐ', 'ও', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', '়', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', '্', 'ৎ', 'ড়', 'ঢ়', 'য়', '১', '২', '৩', '৪', '৫', '৬', '৭', 'ৰ', 'ৱ', '৷', '–', '—', '‘', '’', '“', '”', '…']

# %%
def clean(filter_list, text):
    for ch in filter_list:
        text = text.replace(ch, '')
    text = text.strip()
    return text

# for dataset version 1.2
chars_to_remove = [
    '!', '(', ')', ',', '-', '.', '1', ':', ';', '<', '?', 'R', 'r', '{', '·',
    'я', 'अ', 'छ', 'ब', 'भ', 'य', 'र', 'ल', 'श', 'ৰ', 'ৱ', '৷', '–', '—', 
    '‘', '’', '“', '”', '…', '।'
]

text_words = []
for line in lines:
    text = clean(chars_to_remove, line)
    if text and text != '':
        words = text.split()
        text_words.extend(words)

print("Total words:", len(text_words))
# Out:
# Total words: 80985

# %%
# Unknown ওয়ার্ড এর জন্য UNK টকেন ব্যাবহার করব ।
dictionary = [('UNK', -1)]
# MAX_VOCABULARY_SIZE ধরে কমন (মানে যে শব্দও গুলোর ফ্রিকুয়েন্সি বেশি) সেগুলো নিয়ে নিলাম 
dictionary.extend(
    collections.Counter(text_words).most_common(MAX_VOCABULARY_SIZE - 1)
)

print("Total unique words:", len(dictionary))
print("Dictionary of unique words", dictionary)
# Out:
# Total unique words: 9275
# Dictionary of unique words [('UNK', -1), ('না', 2683), ('করে', 919), ('তার', 750), ('বলল', 742), ('কি', 741), ('মুনা', 709), ('সে', 620), ('একটা', 593), ('আছে', 556), ('কিছু', 551), ('তো', 502), ('কথা', 495), ('হয়', 479), ('হয়ে', 469), ('হবে', 445), ('বকুল', 440), ('বাকের', 434), ('আমি', 432), ('এই', 431), ('কেন', 430), ('সঙ্গে', 398), ('নিয়ে', 383), ('ভাল', 373), ('মনে', 370), ('আমার', 370), ('নেই', 365), ('সাহেব', 360), ('খুব', 305), ('হচ্ছে', 293), ('গেল', 290), ('বললেন', 289), ('দিয়ে', 282), ('তুমি', 282), ('কী', 274), ('হয়েছে', 270), ('থেকে', 269), ('করতে', 267), ('আর', 265), ('এক', 258), ('কিন্তু', 258), ('বসে', 248), ('কোনো', 247), ('বড়', 242), ('আপা', 240), ('হল', 239), ('যে', 235), ('মামুন', 234), ('এখন', 218), ('জন্যে', 218), ('নাকি', 217), ('এ', 216), ('রকম', 214), ('সময়', 213), ('করছে', 212), ('তিনি', 209), ('যায়', 207), ('বাবু', 206), ('চলে', 196), ('সব', 195), ('তাকে', 194), ('ঠিক', 193), ('ভাই', 190), ('চা', 190), ('শওকত', 189), ('গলায়', 183), ('আপনি', 178), ('গেছে', 176), ('খারাপ', 175), ('তোমার', 173), ('কেমন', 172), ('কোন', 170), ('মত', 167), ('এত', 166), ('আজ', 166), ('যেন', 165), ('এসে', 164), ('ছিল', 164), ('কাছে', 163), ('করল', 163), ('যাবে', 162), ('আপনার', 162), ('বলে', 159), ('ঘরে', 156), ('আবার', 153), ('দেখে', 152), ('বকুলের', 151), ('কেউ', 149), ('বলতে', 149), ('স্বরে', 148), ('লাগল', 147), ('যেতে', 146), ('লাগছে', 145), ('যাচ্ছে', 144), ('একা', 144), ('পর', 143), ('তুই', 141), ('বাড়ি', 141), ('কে', 141), ('দিকে', 140), ('আগে', 140), ('বিয়ে', 138), ('মুখ', 137), ('দেখা', 136), ('এবং', 135), ('তোর', 134), ('মুনার', 133), ('এমন', 131), ('বল', 131), ('মধ্যে', 129), ('দিন', 129), ('জি', 126), ('ইচ্ছা', 125), ('শুধু', 123), ('কিছুই', 121), ('থাকে', 121), ('যা', 121), ('এটা', 118), ('রইল', 118), ('মেয়ে', 115), ('ব্যাপার', 115), ('হাত', 113), ('তা', 113), ('দিতে', 112), ('মাথা', 112), ('একটু', 112), ('সত্যি', 111), ('অনেক', 110), ('গিয়ে', 110), ('উঠে', 109), ('দিল', 108), ('আমাকে', 108), ('বেশ', 107), ('লাগে', 107), ('সেই', 107), ('কোথায়', 107), ('বোধ', 106), ('করা', 106), ('ধরে', 105), ('মামা', 104), ('চোখ', 104), ('তাকিয়ে', 104), ('করবে', 102), ('সাহেবের', 100), ('কাজ', 100), ('ও', 99), ('তাই', 99), ('বাকেরের', 99), ('একবার', 95), ('একটি', 95), ('হয়নি', 93), ('সিগারেট', 93), ('দরকার', 93), ('পারে', 92), ('মা', 92), ('একজন', 91), ('জাহানারা', 91), ('অন্য', 90), ('শুরু', 90), ('বিরক্ত', 90), ('রাগ', 90), ('নয়', 90), ('মানে', 89), ('নাম', 89), ('মুখে', 88), ('এর', 87), ('আসবে', 87), ('দেখতে', 86), ('জিজ্ঞেস', 86), ('তাহলে', 85), ('ভয়', 85), ('জহির', 85), ('যদি', 84), ('টাকা', 84), ('অবাক', 84), ('দাঁড়িয়ে', 84), ('এসেছে', 83), ('বাড়িতে', 83), ('শেষ', 83), ('বাসায়', 81), ('হলে', 80), ('চোখে', 80), ('সবাই', 79), ('ফেলে', 79), ('নিজের', 79), ('এল', 79), ('বের', 79), ('রাত', 78), ('পড়ে', 78), ('বলবে', 78), ('এখানে', 78), ('খবর', 78), ('পর্যন্ত', 77), ('ঘর', 77), ('জবাব', 77), ('জানি', 77), ('পাওয়া', 76), ('ডাক্তার', 75), ('সুন্দর', 75), ('স্যার', 75), ('যাব', 73), ('থাকবে', 73), ('ঘুম', 73), ('অফিসে', 72), ('মানুষ', 72), ('খেতে', 72), ('যান', 71), ('আসতে', 70), ('আসছে', 70), ('আছেন', 70), ('গল্প', 70), ('বেশি', 69), ('মন', 69), ('ফেলল', 69), ('ঝামেলা', 69), ('হাসি', 69), ('বন্ধ', 68), ('হুঁ', 68), ('সামনে', 68), ('সেটা', 68), ('জলিল', 68), ('তখন', 67), ('বিয়ের', 67), ('থাকতে', 67), ('ভালই', 67), ('আপনাকে', 67), ('ঐ', 67), ('বুঝতে', 67), ('রাতে', 66), ('তোমাকে', 66), ('মাঝে', 66), ('পানি', 65), ('দেখি', 65), ('এখনো', 65), ('জানে', 65), ('বাবা', 64), ('দেব', 64), ('টিনা', 64), ('হ্যাঁ', 63), ('যাবার', 63), ('ভাবে', 63), ('তারপর', 61), ('ওপর', 60), ('করব', 60), ('ভাবী', 60), ('রিকশা', 59), ('মুনাকে', 59), ('দরজা', 59), ('আরো', 59), ('পছন্দ', 59), ('যখন', 59), ('হঠাৎ', 59), ('বই', 59), ('ছাড়া', 58), ('পা', 57), ('আচ্ছা', 57), ('জ্বর', 57), ('করার', 57), ('থাকলে', 57), ('গম্ভীর', 57), ('চেষ্টা', 56), ('বারান্দায়', 56), ('শরীর', 56), ('আমাদের', 56), ('নিশ্চয়ই', 56), ('তবু', 55), ('আসে', 55), ('করেছে', 55), ('অসুবিধা', 55), ('লতিফা', 55), ('শব্দ', 55), ('খেয়ে', 55), ('ফিরে', 55), ('চায়ের', 55), ('হা', 55), ('নিচু', 54 ...

# %%
# Remove samples with less than 'min_occurrence' occurrences.
# যে শব্দ গুলো 'MIN_OCCURRENCE' থেকে ছোট সেগুলোকে আমরা বাদ দিয়ে দেই
for i in range(len(dictionary)-1, -1, -1):
    # i'th শব্দ কতবার এসেছে সেটা নেই
    occurrence = dictionary[i][1]
    # যদি MIN_OCCURRENCE থেকে ছোট হয় তাহলে আমরা এই শব্দকে dictionary থেক বাদ দেই
    if occurrence < MIN_OCCURRENCE:
        dictionary.pop(i)
    else:
        # যেহেতু আমাদের dictionary টা occurrence এর উপর ভিত্তি করে সর্ট (বেশি থেকে কম) করা 
        # এবং আমরা এটাকে শেষ থেকে শুরুর দিকে ইতারেট করতেছি এই জন্য আমরা যদি কোন শব্দের জন্য
        # occurrence < MIN_OCCURRENCE না পাই তাহলে আমরা লুপ থেকে বের হয়ে যাব। কারণ সবগুলো
        # অলরেডি বাদ পরে গেছে । 
        break

VOCABULARY_SIZE = len(dictionary)
print("Vocabulary size after filter min occurrence word:", VOCABULARY_SIZE)
# Out:
# Vocabulary size after filter min occurrence word: 1185

# %%
word2id = {}
id2word = {}
for i, (word, _)in enumerate(dictionary):
    # প্রত্যেক টা শব্দকে আমরা একটা আইডি এসাইন করে দেই
    word2id[word] = i
    # আইডি থেকে আবার ওয়ার্ড এ ফিরে আসার জন্য ট্রাক রাখি
    id2word[i] = word
print('word2id:', word2id)
print('id2word:', id2word)
# Out:
# word2id: {'UNK': 0, 'না': 1, 'করে': 2, 'তার': 3, 'বলল': 4, 'কি': 5, 'মুনা': 6, 'সে': 7, 'একটা': 8, 'আছে': 9, 'কিছু': 10, 'তো': 11, 'কথা': 12, 'হয়': 13, 'হয়ে': 14, 'হবে': 15, 'বকুল': 16, 'বাকের': 17, 'আমি': 18, 'এই': 19, 'কেন': 20, 'সঙ্গে': 21, 'নিয়ে': 22, 'ভাল': 23, 'মনে': 24, 'আমার': 25, 'নেই': 26, 'সাহেব': 27, 'খুব': 28, 'হচ্ছে': 29, 'গেল': 30, 'বললেন': 31, 'দিয়ে': 32, 'তুমি': 33, 'কী': 34, 'হয়েছে': 35, 'থেকে': 36, 'করতে': 37, 'আর': 38, 'এক': 39, 'কিন্তু': 40, 'বসে': 41, 'কোনো': 42, 'বড়': 43, 'আপা': 44, 'হল': 45, 'যে': 46, 'মামুন': 47, 'এখন': 48, 'জন্যে': 49, 'নাকি': 50, 'এ': 51, 'রকম': 52, 'সময়': 53, 'করছে': 54, 'তিনি': 55, 'যায়': 56, 'বাবু': 57, 'চলে': 58, 'সব': 59, 'তাকে': 60, 'ঠিক': 61, 'ভাই': 62, 'চা': 63, 'শওকত': 64, 'গলায়': 65, 'আপনি': 66, 'গেছে': 67, 'খারাপ': 68, 'তোমার': 69, 'কেমন': 70, 'কোন': 71, 'মত': 72, 'এত': 73, 'আজ': 74, 'যেন': 75, 'এসে': 76, 'ছিল': 77, 'কাছে': 78, 'করল': 79, 'যাবে': 80, 'আপনার': 81, 'বলে': 82, 'ঘরে': 83, 'আবার': 84, 'দেখে': 85, 'বকুলের': 86, 'কেউ': 87, 'বলতে': 88, 'স্বরে': 89, 'লাগল': 90, 'যেতে': 91, 'লাগছে': 92, 'যাচ্ছে': 93, 'একা': 94, 'পর': 95, 'তুই': 96, 'বাড়ি': 97, 'কে': 98, 'দিকে': 99, 'আগে': 100, 'বিয়ে': 101, 'মুখ': 102, 'দেখা': 103, 'এবং': 104, 'তোর': 105, 'মুনার': 106, 'এমন': 107, 'বল': 108, 'মধ্যে': 109, 'দিন': 110, 'জি': 111, 'ইচ্ছা': 112, 'শুধু': 113, 'কিছুই': 114, 'থাকে': 115, 'যা': 116, 'এটা': 117, 'রইল': 118, 'মেয়ে': 119, 'ব্যাপার': 120, 'হাত': 121, 'তা': 122, 'দিতে': 123, 'মাথা': 124, 'একটু': 125, 'সত্যি': 126, 'অনেক': 127, 'গিয়ে': 128, 'উঠে': 129, 'দিল': 130, 'আমাকে': 131, 'বেশ': 132, 'লাগে': 133, 'সেই': 134, 'কোথায়': 135, 'বোধ': 136, 'করা': 137, 'ধরে': 138, 'মামা': 139, 'চোখ': 140, 'তাকিয়ে': 141, 'করবে': 142, 'সাহেবের': 143, 'কাজ': 144, 'ও': 145, 'তাই': 146, 'বাকেরের': 147, 'একবার': 148, 'একটি': 149, 'হয়নি': 150, 'সিগারেট': 151, 'দরকার': 152, 'পারে': 153, 'মা': 154, 'একজন': 155, 'জাহানারা': 156, 'অন্য': 157, 'শুরু': 158, 'বিরক্ত': 159, 'রাগ': 160, 'নয়': 161, 'মানে': 162, 'নাম': 163, 'মুখে': 164, 'এর': 165, 'আসবে': 166, 'দেখতে': 167, 'জিজ্ঞেস': 168, 'তাহলে': 169, 'ভয়': 170, 'জহির': 171, 'যদি': 172, 'টাকা': 173, 'অবাক': 174, 'দাঁড়িয়ে': 175, 'এসেছে': 176, 'বাড়িতে': 177, 'শেষ': 178, 'বাসায়': 179, 'হলে': 180, 'চোখে': 181, 'সবাই': 182, 'ফেলে': 183, 'নিজের': 184, 'এল': 185, 'বের': 186, 'রাত': 187, 'পড়ে': 188, 'বলবে': 189, 'এখানে': 190, 'খবর': 191, 'পর্যন্ত': 192, 'ঘর': 193, 'জবাব': 194, 'জানি': 195, 'পাওয়া': 196, 'ডাক্তার': 197, 'সুন্দর': 198, 'স্যার': 199, 'যাব': 200, 'থাকবে': 201, 'ঘুম': 202, 'অফিসে': 203, 'মানুষ': 204, 'খেতে': 205, 'যান': 206, 'আসতে': 207, 'আসছে': 208, 'আছেন': 209, 'গল্প': 210, 'বেশি': 211, 'মন': 212, 'ফেলল': 213, 'ঝামেলা': 214, 'হাসি': 215, 'বন্ধ': 216, 'হুঁ': 217, 'সামনে': 218, 'সেটা': 219, 'জলিল': 220, 'তখন': 221, 'বিয়ের': 222, 'থাকতে': 223, 'ভালই': 224, 'আপনাকে': 225, 'ঐ': 226, 'বুঝতে': 227, 'রাতে': 228, 'তোমাকে': 229, 'মাঝে': 230, 'পানি': 231, 'দেখি': 232, 'এখনো': 233, 'জানে': 234, 'বাবা': 235, 'দেব': 236, 'টিনা': 237, 'হ্যাঁ': 238, 'যাবার': 239, 'ভাবে': 240, 'তারপর': 241, 'ওপর': 242, 'করব': 243, 'ভাবী': 244, 'রিকশা': 245, 'মুনাকে': 246, 'দরজা': 247, 'আরো': 248, 'পছন্দ': 249, 'যখন': 250, 'হঠাৎ': 251, 'বই': 252, 'ছাড়া': 253, 'পা': 254, 'আচ্ছা': 255, 'জ্বর': 256, 'করার': 257, 'থাকলে': 258, 'গম্ভীর': 259, 'চেষ্টা': 260, 'বারান্দায়': 261, 'শরীর': 262, 'আমাদের': 263, 'নিশ্চয়ই': 264, 'তবু': 265, 'আসে': 266, 'করেছে': 267, 'অসুবিধা': 268, 'লতিফা': 269, 'শব্দ': 270, 'খেয়ে': 271, 'ফিরে': 272, 'চায়ের': 273, 'হা': 274, 'নিচু': 275, 'শুয়ে': 276, 'গায়ে': 277, 'হাতে': 278, 'যাই': 279, 'পড়ল': 280, 'বলা': 281, 'হাসতে': 282, 'ছেলে': 283, 'লোক': 284, 'নতুন': 285, 'ভঙ্গিতে': 286, 'ব্যাপারটা': 287, 'ঠাণ্ডা': 288, 'হয়ত': 289, 'কারণ': 290, 'বলব': 291, 'বাড়ির': 292, 'কত': 293, 'খুবই': 294, 'তবে': 295, 'চুপ': 296, 'অবস্থা': 297, 'সিদ্দিক': 298, 'হাসান': 299, 'পাশে': 300, 'দেয়া': 301, 'নিঃশ্বাস': 302, 'করবেন': 303, 'প্রথম': 304, 'হতে': 305, 'লোকজন': 306, 'অবশ্যি': 307, 'মতো': 308, 'মিয়া': 309, 'শাড়ি': 310, 'বকুলকে': 311, 'এগিয়ে': 312, 'পরে': 313, 'বলছে': 314, 'হবার': 315, 'ধরনের' ...
# id2word: {0: 'UNK', 1: 'না', 2: 'করে', 3: 'তার', 4: 'বলল', 5: 'কি', 6: 'মুনা', 7: 'সে', 8: 'একটা', 9: 'আছে', 10: 'কিছু', 11: 'তো', 12: 'কথা', 13: 'হয়', 14: 'হয়ে', 15: 'হবে', 16: 'বকুল', 17: 'বাকের', 18: 'আমি', 19: 'এই', 20: 'কেন', 21: 'সঙ্গে', 22: 'নিয়ে', 23: 'ভাল', 24: 'মনে', 25: 'আমার', 26: 'নেই', 27: 'সাহেব', 28: 'খুব', 29: 'হচ্ছে', 30: 'গেল', 31: 'বললেন', 32: 'দিয়ে', 33: 'তুমি', 34: 'কী', 35: 'হয়েছে', 36: 'থেকে', 37: 'করতে', 38: 'আর', 39: 'এক', 40: 'কিন্তু', 41: 'বসে', 42: 'কোনো', 43: 'বড়', 44: 'আপা', 45: 'হল', 46: 'যে', 47: 'মামুন', 48: 'এখন', 49: 'জন্যে', 50: 'নাকি', 51: 'এ', 52: 'রকম', 53: 'সময়', 54: 'করছে', 55: 'তিনি', 56: 'যায়', 57: 'বাবু', 58: 'চলে', 59: 'সব', 60: 'তাকে', 61: 'ঠিক', 62: 'ভাই', 63: 'চা', 64: 'শওকত', 65: 'গলায়', 66: 'আপনি', 67: 'গেছে', 68: 'খারাপ', 69: 'তোমার', 70: 'কেমন', 71: 'কোন', 72: 'মত', 73: 'এত', 74: 'আজ', 75: 'যেন', 76: 'এসে', 77: 'ছিল', 78: 'কাছে', 79: 'করল', 80: 'যাবে', 81: 'আপনার', 82: 'বলে', 83: 'ঘরে', 84: 'আবার', 85: 'দেখে', 86: 'বকুলের', 87: 'কেউ', 88: 'বলতে', 89: 'স্বরে', 90: 'লাগল', 91: 'যেতে', 92: 'লাগছে', 93: 'যাচ্ছে', 94: 'একা', 95: 'পর', 96: 'তুই', 97: 'বাড়ি', 98: 'কে', 99: 'দিকে', 100: 'আগে', 101: 'বিয়ে', 102: 'মুখ', 103: 'দেখা', 104: 'এবং', 105: 'তোর', 106: 'মুনার', 107: 'এমন', 108: 'বল', 109: 'মধ্যে', 110: 'দিন', 111: 'জি', 112: 'ইচ্ছা', 113: 'শুধু', 114: 'কিছুই', 115: 'থাকে', 116: 'যা', 117: 'এটা', 118: 'রইল', 119: 'মেয়ে', 120: 'ব্যাপার', 121: 'হাত', 122: 'তা', 123: 'দিতে', 124: 'মাথা', 125: 'একটু', 126: 'সত্যি', 127: 'অনেক', 128: 'গিয়ে', 129: 'উঠে', 130: 'দিল', 131: 'আমাকে', 132: 'বেশ', 133: 'লাগে', 134: 'সেই', 135: 'কোথায়', 136: 'বোধ', 137: 'করা', 138: 'ধরে', 139: 'মামা', 140: 'চোখ', 141: 'তাকিয়ে', 142: 'করবে', 143: 'সাহেবের', 144: 'কাজ', 145: 'ও', 146: 'তাই', 147: 'বাকেরের', 148: 'একবার', 149: 'একটি', 150: 'হয়নি', 151: 'সিগারেট', 152: 'দরকার', 153: 'পারে', 154: 'মা', 155: 'একজন', 156: 'জাহানারা', 157: 'অন্য', 158: 'শুরু', 159: 'বিরক্ত', 160: 'রাগ', 161: 'নয়', 162: 'মানে', 163: 'নাম', 164: 'মুখে', 165: 'এর', 166: 'আসবে', 167: 'দেখতে', 168: 'জিজ্ঞেস', 169: 'তাহলে', 170: 'ভয়', 171: 'জহির', 172: 'যদি', 173: 'টাকা', 174: 'অবাক', 175: 'দাঁড়িয়ে', 176: 'এসেছে', 177: 'বাড়িতে', 178: 'শেষ', 179: 'বাসায়', 180: 'হলে', 181: 'চোখে', 182: 'সবাই', 183: 'ফেলে', 184: 'নিজের', 185: 'এল', 186: 'বের', 187: 'রাত', 188: 'পড়ে', 189: 'বলবে', 190: 'এখানে', 191: 'খবর', 192: 'পর্যন্ত', 193: 'ঘর', 194: 'জবাব', 195: 'জানি', 196: 'পাওয়া', 197: 'ডাক্তার', 198: 'সুন্দর', 199: 'স্যার', 200: 'যাব', 201: 'থাকবে', 202: 'ঘুম', 203: 'অফিসে', 204: 'মানুষ', 205: 'খেতে', 206: 'যান', 207: 'আসতে', 208: 'আসছে', 209: 'আছেন', 210: 'গল্প', 211: 'বেশি', 212: 'মন', 213: 'ফেলল', 214: 'ঝামেলা', 215: 'হাসি', 216: 'বন্ধ', 217: 'হুঁ', 218: 'সামনে', 219: 'সেটা', 220: 'জলিল', 221: 'তখন', 222: 'বিয়ের', 223: 'থাকতে', 224: 'ভালই', 225: 'আপনাকে', 226: 'ঐ', 227: 'বুঝতে', 228: 'রাতে', 229: 'তোমাকে', 230: 'মাঝে', 231: 'পানি', 232: 'দেখি', 233: 'এখনো', 234: 'জানে', 235: 'বাবা', 236: 'দেব', 237: 'টিনা', 238: 'হ্যাঁ', 239: 'যাবার', 240: 'ভাবে', 241: 'তারপর', 242: 'ওপর', 243: 'করব', 244: 'ভাবী', 245: 'রিকশা', 246: 'মুনাকে', 247: 'দরজা', 248: 'আরো', 249: 'পছন্দ', 250: 'যখন', 251: 'হঠাৎ', 252: 'বই', 253: 'ছাড়া', 254: 'পা', 255: 'আচ্ছা', 256: 'জ্বর', 257: 'করার', 258: 'থাকলে', 259: 'গম্ভীর', 260: 'চেষ্টা', 261: 'বারান্দায়', 262: 'শরীর', 263: 'আমাদের', 264: 'নিশ্চয়ই', 265: 'তবু', 266: 'আসে', 267: 'করেছে', 268: 'অসুবিধা', 269: 'লতিফা', 270: 'শব্দ', 271: 'খেয়ে', 272: 'ফিরে', 273: 'চায়ের', 274: 'হা', 275: 'নিচু', 276: 'শুয়ে', 277: 'গায়ে', 278: 'হাতে', 279: 'যাই', 280: 'পড়ল', 281: 'বলা', 282: 'হাসতে', 283: 'ছেলে', 284: 'লোক', 285: 'নতুন', 286: 'ভঙ্গিতে', 287: 'ব্যাপারটা', 288: 'ঠাণ্ডা', 289: 'হয়ত', 290: 'কারণ', 291: 'বলব', 292: 'বাড়ির', 293: 'কত', 294: 'খুবই', 295: 'তবে', 296: 'চুপ', 297: 'অবস্থা', 298: 'সিদ্দিক', 299: 'হাসান', 300: 'পাশে', 301: 'দেয়া', 302: 'নিঃশ্বাস', 303: 'করবেন', 304: 'প্রথম', 305: 'হতে', 306: 'লোকজন', 307: 'অবশ্যি', 308: 'মতো', 309: 'মিয়া', 310: 'শাড়ি', 311: 'বকুলকে', 312: 'এগিয়ে', 313: 'পরে', 314: 'বলছে', 315: 'হবার', 316: 'ধ ...

# %%
data = []
unk_word_count = 0
for word in text_words:
    # Retrieve a word id, or assign it index 0 ('UNK') if not in dictionary.
    # text_words এর প্রতিটি শব্দকে একটা আইডি দিয়ে দেই ।
    # যদি শব্দটা টা word2id মধ্যে পাওয়া না যায় তাহলে এটা একটা UNK ক্যাটাগরির শব্দ 
    # এই জন্য এটাকে আমরা ০ আইডি দিয়ে দিব 
    index = word2id.get(word, 0)
    
    # UNK টকেনের ফ্রিকুয়েন্সি কেমন হয় সেটা ট্রাক রাখা
    if index == 0:
        unk_word_count += 1
    # প্রতিটা শব্দের বিপরীতে আমরা সেই শব্দের আইডি কে রাখলাম এবং এই ডাটা দিয়েই আমরা আমাদের মডেল 
    # ট্রেনিং করব । 
    data.append(index)
# UNK এর ফ্রিকুয়েন্সি ডিকশনারিতে এড করে দিলাম
dictionary[0] = ('UNK', unk_word_count)

# শব্দকে আইডি দেয়ার পরের অবস্থা 
print("data        :", data)
print("Totla data  :", len(data))
print('-' * 50)
# আইডি থেকে আবার শব্দে ফিরে আসার পরের অবস্থা
print("data in text:", [id2word[id] for id in data])
print('-' * 50)


print("Words count:", len(text_words))
print("Unique words:", len(set(text_words)))
print("Vocabulary size:", VOCABULARY_SIZE)
print("Most common words:", dictionary[:20])
# Out:
# data        : [962, 78, 76, 6, 764, 167, 260, 79, 0, 73, 350, 114, 103, 30, 1, 0, 103, 56, 1, 38, 48, 11, 397, 245, 36, 0, 148, 764, 0, 731, 1024, 0, 0, 36, 51, 192, 207, 28, 211, 180, 963, 964, 0, 808, 48, 351, 0, 0, 107, 10, 187, 150, 265, 106, 809, 92, 0, 965, 187, 35, 3, 139, 64, 27, 149, 601, 0, 107, 504, 379, 75, 246, 0, 0, 538, 7, 52, 303, 6, 853, 398, 28, 732, 325, 561, 0, 0, 0, 14, 9, 672, 334, 1025, 0, 0, 0, 123, 7, 896, 261, 0, 0, 254, 0, 0, 0, 310, 1105, 15, 285, 0, 310, 966, 304, 733, 35, 148, 0, 626, 318, 38, 0, 80, 1, 6, 254, 659, 659, 732, 0, 90, 539, 367, 196, 93, 311, 0, 0, 430, 562, 0, 0, 0, 0, 108, 0, 34, 15, 16, 0, 0, 0, 289, 0, 539, 765, 132, 68, 93, 6, 24, 24, 0, 37, 260, 79, 0, 0, 0, 34, 15, 0, 0, 1, 157, 10, 0, 286, 7, 854, 380, 0, 1025, 0, 247, 0, 87, 312, 208, 1, 6, 275, 89, 563, 16, 19, 16, 16, 368, 368, 474, 475, 99, 64, 27, 0, 855, 8, 0, 37, 431, 133, 0, 0, 19, 0, 34, 108, 16, 368, 368, 4, 235, 6, 44, 176, 64, 27, 380, 65, 31, 105, 700, 96, 0, 247, 0, 284, 9, 212, 115, 340, 0, 15, 602, 0, 11, 0, 253, 10, 26, 16, 124, 275, 2, 213, 3, 181, 231, 208, 235, 85, 0, 248, 603, 540, 897, 12, 359, 55, 148, 603, 318, 107, 59, 12, 369, 46, 604, 91, 112, 2, 0, 0, 0, 0, 72, 102, 265, 0, 11, 42, 0, 232, 1, 967, 485, 133, 113, 0, 6, 84, 380, 0, 64, 27, 627, 65, 0, 57, 57, 57, 0, 164, 83, 561, 7, 188, 541, 0, 486, 1106, 3, 124, 138, 399, 193, 397, 2, 276, 115, 64, 27, 334, 673, 603, 855, 1107, 411, 0, 1, 57, 368, 368, 474, 86, 99, 64, 27, 0, 32, 855, 247, 0, 0, 1, 0, 0, 57, 247, 898, 64, 27, 106, 99, 0, 0, 1, 42, 52, 290, 0, 86, 0, 0, 2, 8, 564, 0, 287, 0, 0, 86, 102, 0, 381, 14, 400, 39, 0, 124, 899, 0, 7, 3, 0, 34, 59, 0, 260, 79, 0, 59, 0, 140, 36, 231, 0, 605, 114, 103, 93, 1, 64, 27, 0, 89, 0, 0, 0, 766, 1, 16, 124, 1026, 1, 3, 565, 505, 262, 0, 0, 606, 90, 6, 810, 89, 4, 139, 73, 43, 329, 277, 121, 0, 61, 1, 64, 27, 10, 31, 1, 6, 248, 10, 189, 968, 4, 1, 900, 0, 22, 3, 674, 83, 561, 51, 177, 401, 459, 674, 193, 0, 139, 104, 856, 542, 0, 115, 6, 16, 104, 57, 106, 0, 734, 350, 265, 543, 401, 0, 0, 35, 39, 0, 8, 0, 0, 300, 86, 0, 1027, 0, 0, 857, 0, 8, 735, 421, 767, 0, 3, 0, 0, 0, 675, 0, 0, 190, 0, 1108, 0, 266, 0, 0, 8, 43, 0, 0, 0, 64, 27, 0, 811, 134, 969, 216, 2, 812, 3, 319, 901, 0, 0, 0, 0, 0, 0, 0, 0, 7, 969, 74, 38, 0, 858, 26, 6, 674, 83, 445, 0, 57, 0, 99, 140, 0, 141, 9, 6, 4, 538, 1028, 217, 211, 57, 194, 130, 1, 6, 4, 57, 96, 125, 340, 0, 11, 18, 0, 0, 57, 261, 76, 382, 39, 0, 0, 543, 8, 0, 660, 9, 0, 97, 36, 87, 566, 190, 544, 301, 13, 57, 768, 0, 0, 0, 48, 125, 0, 99, 412, 412, 0, 701, 91, 158, 267, 57, 335, 267, 6, 44, 179, 0, 3, 1028, 0, 158, 2, 6, 0, 587, 261, 76, 0, 231, 0, 57, 141, 141, 628, 3, 102, 85, 24, 29, 7, 10, 189, 295, 0, 36, 7, 370, 10, 82, 1, 168, 37, 13, 6, 4, 57, 10, 859, 217, 82, 0, 17, 62, 74, 517, 168, 588, 34, 168, 588, 69, 12, 460, 2, 108, 0, 12, 0, 446, 567, 0, 602, 57, 769, 37, 90, 6, 476, 702, 4, 108, 34, 4, 4, 34, 320, 105, 0, 50, 101, 54, 96, 34, 0, 18, 10, 0, 114, 0, 57, 769, 2, 4, 629, 18, 114, 195, 1, 6, 159, 89, 4, 518, 0, 20, 126, 371, 88, 268, 34, 126, 12, 568, 7, 34, 545, 0, 84, 172, 703, 168, 2, 96, 859, 238, 101, 142, 57, 102, 0, 676, 75, 126, 371, 7, 0, 37, 432, 1, 19, 0, 49, 7, 75, 0, 6, 380, 65, 4, 157, 99, 102, 0, 704, 20, 0, 25, 99, 57, 474, 6, 505, 89, 4, 0, 182, 51, 52, 504, 0, 75, 18, 0, 8, 0, 2, 0, 8, 119, 172, 8, 970, 249, 2, 104, 101, 2, 169, 3, 109, 0, 114, 26, 96, 250, 43, 0, 221, 0, 51, 52, 249, 2, 8, 902, 101, 971, 336, 96, 232, 1029, 903, 604, 0, 6, 44, 23, 15, 1, 40, 96, 6, 44, 6, 44, 766, 20, 113, 44, 0, 519, 43, 44, 21, 84, 6, 34, 49, 255, 44, 461, 101, 321, 770, 904, 57, 38, 10, 168, 79, 1, 7, 24, 45, 132, 477, 905, 6, 565, 8, 302, 183, 4, 0, 87, 131, 813, 37, 0, 1, 57, 1109, 89, 4, 34, 46, 33, 108, 607, 705, 0, 0, 906, 972, 0, 506, 95, 261, 445, 0, 906, 972, 507, 11, 0, 57, 34, 75, 88, 0, 6, 122, 0, 49, 341, 79, 1, 0, 674, 83, 561, 19, 0, 10, 422, 9, 8, 0, 350, 8, 0, 1027, 3, 300, 0, 196, 0, 0, 973, 0, 8, 421, 767, 0, 0, 10, 857, 422, 9, ...
# Totla data  : 80985
# --------------------------------------------------
# data in text: ['গেটের', 'কাছে', 'এসে', 'মুনা', 'ঘড়ি', 'দেখতে', 'চেষ্টা', 'করল', 'UNK', 'এত', 'ছোট', 'কিছুই', 'দেখা', 'গেল', 'না', 'UNK', 'দেখা', 'যায়', 'না', 'আর', 'এখন', 'তো', 'অন্ধকার', 'রিকশা', 'থেকে', 'UNK', 'একবার', 'ঘড়ি', 'UNK', 'সাড়ে', 'সাত', 'UNK', 'UNK', 'থেকে', 'এ', 'পর্যন্ত', 'আসতে', 'খুব', 'বেশি', 'হলে', 'চার', 'মিনিট', 'UNK', 'কাজেই', 'এখন', 'বাজে', 'UNK', 'UNK', 'এমন', 'কিছু', 'রাত', 'হয়নি', 'তবু', 'মুনার', 'অস্বস্তি', 'লাগছে', 'UNK', 'ফিরতে', 'রাত', 'হয়েছে', 'তার', 'মামা', 'শওকত', 'সাহেব', 'একটি', 'কথাও', 'UNK', 'এমন', 'ভাব', 'করেছেন', 'যেন', 'মুনাকে', 'UNK', 'UNK', 'আজও', 'সে', 'রকম', 'করবেন', 'মুনা', 'গেট', 'খুলে', 'খুব', 'সাবধানে', 'ভেতরে', 'ঢুকল', 'UNK', 'UNK', 'UNK', 'হয়ে', 'আছে', 'সকালে', 'বাবুকে', 'দুবার', 'UNK', 'UNK', 'UNK', 'দিতে', 'সে', 'দেয়নি', 'বারান্দায়', 'UNK', 'UNK', 'পা', 'UNK', 'UNK', 'UNK', 'শাড়ি', 'নষ্ট', 'হবে', 'নতুন', 'UNK', 'শাড়ি', 'আজই', 'প্রথম', 'পরা', 'হয়েছে', 'একবার', 'UNK', 'লেগে', 'গেলে', 'আর', 'UNK', 'যাবে', 'না', 'মুনা', 'পা', 'টিপে', 'টিপে', 'সাবধানে', 'UNK', 'লাগল', 'মামার', 'গলা', 'পাওয়া', 'যাচ্ছে', 'বকুলকে', 'UNK', 'UNK', 'সকাল', 'বেলা', 'UNK', 'UNK', 'UNK', 'UNK', 'বল', 'UNK', 'কী', 'হবে', 'বকুল', 'UNK', 'UNK', 'UNK', 'হয়ত', 'UNK', 'মামার', 'মেজাজ', 'বেশ', 'খারাপ', 'যাচ্ছে', 'মুনা', 'মনে', 'মনে', 'UNK', 'করতে', 'চেষ্টা', 'করল', 'UNK', 'UNK', 'UNK', 'কী', 'হবে', 'UNK', 'UNK', 'না', 'অন্য', 'কিছু', 'UNK', 'ভঙ্গিতে', 'সে', 'দরজার', 'কড়া', 'UNK', 'দুবার', 'UNK', 'দরজা', 'UNK', 'কেউ', 'এগিয়ে', 'আসছে', 'না', 'মুনা', 'নিচু', 'স্বরে', 'ডাকল', 'বকুল', 'এই', 'বকুল', 'বকুল', 'ভয়ে', 'ভয়ে', 'তাকাল', 'বাবার', 'দিকে', 'শওকত', 'সাহেব', 'UNK', 'উঠলেন', 'একটা', 'UNK', 'করতে', 'একদিন', 'লাগে', 'UNK', 'UNK', 'এই', 'UNK', 'কী', 'বল', 'বকুল', 'ভয়ে', 'ভয়ে', 'বলল', 'বাবা', 'মুনা', 'আপা', 'এসেছে', 'শওকত', 'সাহেব', 'কড়া', 'গলায়', 'বললেন', 'তোর', 'পড়া', 'তুই', 'UNK', 'দরজা', 'UNK', 'লোক', 'আছে', 'মন', 'থাকে', 'বাইরে', 'UNK', 'হবে', 'কিভাবে', 'UNK', 'তো', 'UNK', 'ছাড়া', 'কিছু', 'নেই', 'বকুল', 'মাথা', 'নিচু', 'করে', 'ফেলল', 'তার', 'চোখে', 'পানি', 'আসছে', 'বাবা', 'দেখে', 'UNK', 'আরো', 'রেগে', 'যাবেন', 'আজেবাজে', 'কথা', 'বলবেন', 'তিনি', 'একবার', 'রেগে', 'গেলে', 'এমন', 'সব', 'কথা', 'বলেন', 'যে', 'মরে', 'যেতে', 'ইচ্ছা', 'করে', 'UNK', 'UNK', 'UNK', 'UNK', 'মত', 'মুখ', 'তবু', 'UNK', 'তো', 'কোনো', 'UNK', 'দেখি', 'না', 'একশ', 'টাকার', 'লাগে', 'শুধু', 'UNK', 'মুনা', 'আবার', 'কড়া', 'UNK', 'শওকত', 'সাহেব', 'উঁচু', 'গলায়', 'UNK', 'বাবু', 'বাবু', 'বাবু', 'UNK', 'মুখে', 'ঘরে', 'ঢুকল', 'সে', 'পড়ে', 'ক্লাস', 'UNK', 'রোজ', 'সন্ধ্যায়', 'তার', 'মাথা', 'ধরে', 'বলেই', 'ঘর', 'অন্ধকার', 'করে', 'শুয়ে', 'থাকে', 'শওকত', 'সাহেব', 'বাবুকে', 'দেখেই', 'রেগে', 'উঠলেন', 'কানে', 'শুনতে', 'UNK', 'না', 'বাবু', 'ভয়ে', 'ভয়ে', 'তাকাল', 'বকুলের', 'দিকে', 'শওকত', 'সাহেব', 'UNK', 'দিয়ে', 'উঠলেন', 'দরজা', 'UNK', 'UNK', 'না', 'UNK', 'UNK', 'বাবু', 'দরজা', 'খুলল', 'শওকত', 'সাহেব', 'মুনার', 'দিকে', 'UNK', 'UNK', 'না', 'কোনো', 'রকম', 'কারণ', 'UNK', 'বকুলের', 'UNK', 'UNK', 'করে', 'একটা', 'চড়', 'UNK', 'ব্যাপারটা', 'UNK', 'UNK', 'বকুলের', 'মুখ', 'UNK', 'লাল', 'হয়ে', 'উঠল', 'এক', 'UNK', 'মাথা', 'অনেকখানি', 'UNK', 'সে', 'তার', 'UNK', 'কী', 'সব', 'UNK', 'চেষ্টা', 'করল', 'UNK', 'সব', 'UNK', 'চোখ', 'থেকে', 'পানি', 'UNK', 'পড়ছে', 'কিছুই', 'দেখা', 'যাচ্ছে', 'না', 'শওকত', 'সাহেব', 'UNK', 'স্বরে', 'UNK', 'UNK', 'UNK', 'করিস', 'না', 'বকুল', 'মাথা', 'তুলল', 'না', 'তার', 'ছোট্ট', 'হালকা', 'শরীর', 'UNK', 'UNK', 'উঠতে', 'লাগল', 'মুনা', 'শান্ত', 'স্বরে', 'বলল', 'মামা', 'এত', 'বড়', 'মেয়ের', 'গায়ে', 'হাত', 'UNK', 'ঠিক', 'না', 'শওকত', 'সাহেব', 'কিছু', 'বললেন', 'না', 'মুনা', 'আরো', 'কিছু', 'বলবে', 'ভেবেছিল', 'বলল', 'না', 'নিজেকে', 'UNK', 'নিয়ে', 'তার', 'শোবার', 'ঘরে', 'ঢুকল', 'এ', 'বাড়িতে', 'দুটি', 'মাত্র', 'শোবার', 'ঘর', 'UNK', 'মামা', 'এবং', 'মামি', 'থাকেন', 'UNK', 'থাকে', 'মুনা', 'বকুল', 'এবং', 'বাবু', 'মুনার', 'UNK', 'অসম্ভব', 'ছোট', 'তবু', 'সেখানে', 'দুটি', 'UNK', 'UNK', 'হয়েছে', 'এক', 'UNK', 'একটা', 'UNK', 'UNK', 'পাশে', 'বকুলের', 'UNK', 'টেবিল', 'UNK', 'UNK', 'ফাঁকা', 'UNK', 'একটা', 'বিশাল', 'কালো', 'রঙের', 'UNK', 'তার', 'UNK', 'UNK', 'UNK', 'ভেতর', 'UNK', 'UNK',  ...
# --------------------------------------------------
# Words count: 80985
# Unique words: 9274
# Vocabulary size: 1185
# Most common words: [('UNK', 16617), ('না', 2683), ('করে', 919), ('তার', 750), ('বলল', 742), ('কি', 741), ('মুনা', 709), ('সে', 620), ('একটা', 593), ('আছে', 556), ('কিছু', 551), ('তো', 502), ('কথা', 495), ('হয়', 479), ('হয়ে', 469), ('হবে', 445), ('বকুল', 440), ('বাকের', 434), ('আমি', 432), ('এই', 431)]

# %%
data_index = 0
# Generate training batch for the skip-gram model.
def next_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # get window size (words left and right + current one).
    span = 2 * skip_window + 1
    # difine a deque buffer to store span words
    # buffer words will change over iteration
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    # select span of words
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    # prepare batch data
    for i in range(batch_size // num_skips):
        # for span = 7 and skip_window = 3
        # span range = [0, 1, 2, 3, 4, 5, 6]
        # 3 will be discard 
        # context_word = [0, 1, 2, 4, 5, 6]
        context_words = [w for w in range(span) if w != skip_window]
        # randomly take `num_skips` sample from context_word
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            # j = 0 মুনা, j = 1 মুন
            batch[i * num_skips + j] = buffer[skip_window]
            # j = 0 গেটের, j = 1 এসে
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            # if we reach end to take '0 to span' words
            buffer.extend(data[0:span])
            # update data index
            data_index = span
        else:
            # update buffer by new word
            buffer.append(data[data_index])
            data_index += 1
    # শেষের শব্দগুলো যাতে বাদ না পরে এই জন্য ইনডেক্স টা আপডেট করে দিলাম
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch_x, batch_y = next_batch(BATCH_SIZE, NUM_SKIPS, SKIP_WINDOW)
print("shape target:", batch_x.shape)
print('shape context:', batch_y.shape)
print('-' * 50)

print('target word :', end='')
for i in range(len(batch_x)):
    print(id2word[batch_x[i]], end=',')
print('')
print('-' * 50)

print("context word:", end='')
for i in range(len(batch_x)):
    print(id2word[batch_y[i][0]], end=',')
# Out:
# shape target: (1024,)
# shape context: (1024, 1)
# --------------------------------------------------
# target word:মুনা,মুনা,ঘড়ি,ঘড়ি,দেখতে,দেখতে,চেষ্টা,চেষ্টা,করল,করল,UNK,UNK,এত,এত,ছোট,ছোট,কিছুই,কিছুই,দেখা,দেখা,গেল,গেল,না,না,UNK,UNK,দেখা,দেখা,যায়,যায়,না,না,আর,আর,এখন,এখন,তো,তো,অন্ধকার,অন্ধকার,রিকশা,রিকশা,থেকে,থেকে,UNK,UNK,একবার,একবার,ঘড়ি,ঘড়ি,UNK,UNK,সাড়ে,সাড়ে,সাত,সাত,UNK,UNK,UNK,UNK,থেকে,থেকে,এ,এ,পর্যন্ত,পর্যন্ত,আসতে,আসতে,খুব,খুব,বেশি,বেশি,হলে,হলে,চার,চার,মিনিট,মিনিট,UNK,UNK,কাজেই,কাজেই,এখন,এখন,বাজে,বাজে,UNK,UNK,UNK,UNK,এমন,এমন,কিছু,কিছু,রাত,রাত,হয়নি,হয়নি,তবু,তবু,মুনার,মুনার,অস্বস্তি,অস্বস্তি,লাগছে,লাগছে,UNK,UNK,ফিরতে,ফিরতে,রাত,রাত,হয়েছে,হয়েছে,তার,তার,মামা,মামা,শওকত,শওকত,সাহেব,সাহেব,একটি,একটি,কথাও,কথাও,UNK,UNK,এমন,এমন,ভাব,ভাব,করেছেন,করেছেন,যেন,যেন,মুনাকে,মুনাকে,UNK,UNK,UNK,UNK,আজও,আজও,সে,সে,রকম,রকম,করবেন,করবেন,মুনা,মুনা,গেট,গেট,খুলে,খুলে,খুব,খুব,সাবধানে,সাবধানে,ভেতরে,ভেতরে,ঢুকল,ঢুকল,UNK,UNK,UNK,UNK,UNK,UNK,হয়ে,হয়ে,আছে,আছে,সকালে,সকালে,বাবুকে,বাবুকে,দুবার,দুবার,UNK,UNK,UNK,UNK,UNK,UNK,দিতে,দিতে,সে,সে,দেয়নি,দেয়নি,বারান্দায়,বারান্দায়,UNK,UNK,UNK,UNK,পা,পা,UNK,UNK,UNK,UNK,UNK,UNK,শাড়ি,শাড়ি,নষ্ট,নষ্ট,হবে,হবে,নতুন,নতুন,UNK,UNK,শাড়ি,শাড়ি,আজই,আজই,প্রথম,প্রথম,পরা,পরা,হয়েছে,হয়েছে,একবার,একবার,UNK,UNK,লেগে,লেগে,গেলে,গেলে,আর,আর,UNK,UNK,যাবে,যাবে,না,না,মুনা,মুনা,পা,পা,টিপে,টিপে,টিপে,টিপে,সাবধানে,সাবধানে,UNK,UNK,লাগল,লাগল,মামার,মামার,গলা,গলা,পাওয়া,পাওয়া,যাচ্ছে,যাচ্ছে,বকুলকে,বকুলকে,UNK,UNK,UNK,UNK,সকাল,সকাল,বেলা,বেলা,UNK,UNK,UNK,UNK,UNK,UNK,UNK,UNK,বল,বল,UNK,UNK,কী,কী,হবে,হবে,বকুল,বকুল,UNK,UNK,UNK,UNK,UNK,UNK,হয়ত,হয়ত,UNK,UNK,মামার,মামার,মেজাজ,মেজাজ,বেশ,বেশ,খারাপ,খারাপ,যাচ্ছে,যাচ্ছে,মুনা,মুনা,মনে,মনে,মনে,মনে,UNK,UNK,করতে,করতে,চেষ্টা,চেষ্টা,করল,করল,UNK,UNK,UNK,UNK,UNK,UNK,কী,কী,হবে,হবে,UNK,UNK,UNK,UNK,না,না,অন্য,অন্য,কিছু,কিছু,UNK,UNK,ভঙ্গিতে,ভঙ্গিতে,সে,সে,দরজার,দরজার,কড়া,কড়া,UNK,UNK,দুবার,দুবার,UNK,UNK,দরজা,দরজা,UNK,UNK,কেউ,কেউ,এগিয়ে,এগিয়ে,আসছে,আসছে,না,না,মুনা,মুনা,নিচু,নিচু,স্বরে,স্বরে,ডাকল,ডাকল,বকুল,বকুল,এই,এই,বকুল,বকুল,বকুল,বকুল,ভয়ে,ভয়ে,ভয়ে,ভয়ে,তাকাল,তাকাল,বাবার,বাবার,দিকে,দিকে,শওকত,শওকত,সাহেব,সাহেব,UNK,UNK,উঠলেন,উঠলেন,একটা,একটা,UNK,UNK,করতে,করতে,একদিন,একদিন,লাগে,লাগে,UNK,UNK,UNK,UNK,এই,এই,UNK,UNK,কী,কী,বল,বল,বকুল,বকুল,ভয়ে,ভয়ে,ভয়ে,ভয়ে,বলল,বলল,বাবা,বাবা,মুনা,মুনা,আপা,আপা,এসেছে,এসেছে,শওকত,শওকত,সাহেব,সাহেব,কড়া,কড়া,গলায়,গলায়,বললেন,বললেন,তোর,তোর,পড়া,পড়া,তুই,তুই,UNK,UNK,দরজা,দরজা,UNK,UNK,লোক,লোক,আছে,আছে,মন,মন,থাকে,থাকে,বাইরে,বাইরে,UNK,UNK,হবে,হবে,কিভাবে,কিভাবে,UNK,UNK,তো,তো,UNK,UNK,ছাড়া,ছাড়া,কিছু,কিছু,নেই,নেই,বকুল,বকুল,মাথা,মাথা,নিচু,নিচু,করে,করে,ফেলল,ফেলল,তার,তার,চোখে,চোখে,পানি,পানি,আসছে,আসছে,বাবা,বাবা,দেখে,দেখে,UNK,UNK,আরো,আরো,রেগে,রেগে,যাবেন,যাবেন,আজেবাজে,আজেবাজে,কথা,কথা,বলবেন,বলবেন,তিনি,তিনি,একবার,একবার,রেগে,রেগে,গেলে,গেলে,এমন,এমন,সব,সব,কথা,কথা,বলেন,বলেন,যে,যে,মরে,মরে,যেতে,যেতে,ইচ্ছা,ইচ্ছা,করে,করে,UNK,UNK,UNK,UNK,UNK,UNK,UNK,UNK,মত,মত,মুখ,মুখ,তবু,তবু,UNK,UNK,তো,তো,কোনো,কোনো,UNK,UNK,দেখি,দেখি,না,না,একশ,একশ,টাকার,টাকার,লাগে,লাগে,শুধু,শুধু,UNK,UNK,মুনা,মুনা,আবার,আবার,কড়া,কড়া,UNK,UNK,শওকত,শওকত,সাহেব,সাহেব,উঁচু,উঁচু,গলায়,গলায়,UNK,UNK,বাবু,বাবু,বাবু,বাবু,বাবু,বাবু,UNK,UNK,মুখে,মুখে,ঘরে,ঘরে,ঢুকল,ঢুকল,সে,সে,পড়ে,পড়ে,ক্লাস,ক্লাস,UNK,UNK,রোজ,রোজ,সন্ধ্যায়,সন্ধ্যায়,তার,তার,মাথা,মাথা,ধরে,ধরে,বলেই,বলেই,ঘর,ঘর,অন্ধকার,অন্ধকার,করে,করে,শুয়ে,শুয়ে,থাকে,থাকে,শওকত,শওকত,সাহেব,সাহেব,বাবুকে,বাবুকে,দেখেই,দেখেই,রেগে,রেগে,উঠলেন,উঠলেন,কানে,কানে,শুনতে,শুনতে,UNK,UNK,না,না,বাবু,বাবু,ভয়ে,ভয়ে,ভয়ে,ভয়ে,তাকাল,তাকাল,বকুলের,বকুলের,দিকে,দিকে,শওকত,শওকত,সাহেব,সাহেব,UNK,UNK,দিয়ে,দিয়ে,উঠলেন,উঠলেন,দরজা,দরজা,UNK,UNK,UNK,UNK,না,না,UNK,UNK,UNK,UNK,বাবু,বাবু,দরজা,দরজা,খুলল,খুলল,শওকত,শওকত,সাহেব,সাহেব,মুনার,মুনার,দিকে,দিকে,UNK,UNK,UNK,UNK,না,না,কোনো,কোনো,রকম,রকম,কারণ,কারণ,UNK,UNK,বকুলের,বকুলের,UNK,UNK,UNK,UNK,করে,করে,একটা,একটা,চড়,চড়,UNK,UNK,ব্যাপারটা,ব্যাপারটা,UNK,UNK,UNK,UNK,বকুলের,বকুলের,মুখ,মুখ,UNK,UNK,লাল,লাল,হয়ে,হয়ে,উঠল,উঠল,এক,এক,UNK,UNK,মাথা,মাথা,অনেকখানি,অনেকখানি,UNK,UNK,সে,সে,তার,তার,UNK,UNK,কী,কী,সব,সব,UNK,UNK,চেষ্টা,চেষ্টা,করল,করল,UNK,UNK,সব,সব,UNK,UNK,চোখ,চোখ,থেকে,থেকে,পানি,পানি,UNK,UNK,পড়ছে,পড়ছে,কিছুই,কিছুই,দেখা,দেখা,যাচ্ছে,যাচ্ছে,না,না,শওকত,শওকত,সাহেব,সাহেব,UNK,UNK,স্বরে,স্বরে,UNK,UNK,UNK,UNK,UNK,UNK,করিস,করিস,না,না,বকুল,বকুল,মাথা,মাথা,তুলল,তুলল,না,না,তার,তার,ছোট্ট,ছোট্ট,হালকা,হালক ...
# --------------------------------------------------
# context word:কাছে,দেখতে,কাছে,চেষ্টা,ঘড়ি,মুনা,মুনা,দেখতে,দেখতে,এত,চেষ্টা,ছোট,UNK,করল,এত,UNK,এত,গেল,না,কিছুই,না,দেখা,যায়,কিছুই,দেখা,যায়,গেল,না,না,UNK,তো,দেখা,যায়,না,রিকশা,তো,রিকশা,থেকে,আর,থেকে,একবার,এখন,অন্ধকার,UNK,থেকে,UNK,সাড়ে,UNK,একবার,UNK,UNK,UNK,UNK,সাত,ঘড়ি,UNK,UNK,সাড়ে,UNK,পর্যন্ত,আসতে,সাত,খুব,পর্যন্ত,আসতে,খুব,খুব,এ,এ,হলে,চার,মিনিট,বেশি,UNK,খুব,মিনিট,UNK,চার,চার,মিনিট,বাজে,মিনিট,বাজে,UNK,কাজেই,এখন,UNK,এখন,কিছু,বাজে,UNK,বাজে,হয়নি,এমন,UNK,কিছু,অস্বস্তি,রাত,লাগছে,রাত,রাত,UNK,লাগছে,UNK,অস্বস্তি,তবু,রাত,ফিরতে,তার,হয়েছে,ফিরতে,UNK,UNK,মামা,হয়েছে,শওকত,হয়েছে,সাহেব,সাহেব,কথাও,তার,UNK,কথাও,সাহেব,সাহেব,এমন,কথাও,সাহেব,একটি,ভাব,UNK,করেছেন,UNK,UNK,UNK,মুনাকে,UNK,আজও,UNK,মুনাকে,UNK,সে,করবেন,মুনাকে,মুনা,UNK,আজও,সে,খুলে,সে,রকম,সে,করবেন,মুনা,খুব,গেট,সাবধানে,মুনা,ভেতরে,গেট,UNK,খুব,UNK,সাবধানে,হয়ে,UNK,UNK,আছে,ঢুকল,UNK,সকালে,UNK,বাবুকে,দুবার,UNK,হয়ে,সকালে,হয়ে,বাবুকে,UNK,UNK,দুবার,সে,দুবার,UNK,দেয়নি,সে,UNK,UNK,UNK,সে,UNK,UNK,UNK,সে,পা,বারান্দায়,UNK,UNK,UNK,UNK,UNK,UNK,নষ্ট,পা,শাড়ি,UNK,হবে,হবে,UNK,শাড়ি,UNK,আজই,নষ্ট,আজই,শাড়ি,নতুন,পরা,নতুন,UNK,হয়েছে,UNK,UNK,একবার,একবার,পরা,গেলে,লেগে,গেলে,আর,UNK,গেলে,লেগে,যাবে,UNK,যাবে,লেগে,আর,পা,গেলে,টিপে,আর,যাবে,টিপে,টিপে,না,মুনা,না,সাবধানে,টিপে,টিপে,পা,গলা,টিপে,মামার,সাবধানে,গলা,লাগল,বকুলকে,মামার,মামার,UNK,পাওয়া,গলা,যাচ্ছে,সকাল,UNK,যাচ্ছে,যাচ্ছে,UNK,UNK,UNK,UNK,UNK,UNK,UNK,UNK,বেলা,UNK,বেলা,UNK,কী,UNK,কী,UNK,হবে,UNK,হবে,UNK,বকুল,UNK,UNK,হয়ত,UNK,হয়ত,UNK,UNK,হয়ত,UNK,মামার,বেশ,হয়ত,UNK,মেজাজ,UNK,যাচ্ছে,UNK,মুনা,মনে,মামার,মনে,মেজাজ,যাচ্ছে,মনে,UNK,মুনা,মুনা,UNK,মনে,চেষ্টা,UNK,করল,করতে,মনে,UNK,UNK,কী,চেষ্টা,করল,UNK,করল,হবে,হবে,UNK,UNK,UNK,কী,না,হবে,UNK,অন্য,UNK,কিছু,না,অন্য,ভঙ্গিতে,সে,কিছু,কড়া,অন্য,কিছু,UNK,কড়া,সে,ভঙ্গিতে,UNK,UNK,কড়া,দরজা,UNK,দুবার,কেউ,দুবার,এগিয়ে,UNK,আসছে,UNK,দরজা,কেউ,না,নিচু,UNK,আসছে,এগিয়ে,নিচু,ডাকল,না,আসছে,এই,না,নিচু,স্বরে,নিচু,বকুল,বকুল,বকুল,বকুল,ভয়ে,তাকাল,এই,বকুল,তাকাল,বাবার,বকুল,বকুল,দিকে,দিকে,ভয়ে,ভয়ে,UNK,UNK,তাকাল,দিকে,শওকত,শওকত,দিকে,UNK,একটা,একদিন,UNK,UNK,করতে,একটা,উঠলেন,করতে,একটা,UNK,একদিন,UNK,এই,UNK,UNK,UNK,UNK,বল,এই,ভয়ে,এই,বকুল,কী,UNK,ভয়ে,বলল,ভয়ে,বলল,বল,বকুল,ভয়ে,আপা,বলল,বলল,আপা,মুনা,বাবা,সাহেব,মুনা,আপা,এসেছে,শওকত,আপা,এসেছে,সাহেব,সাহেব,তোর,তুই,পড়া,কড়া,বললেন,তুই,বললেন,তোর,UNK,লোক,তোর,আছে,UNK,তুই,UNK,মন,UNK,থাকে,মন,লোক,থাকে,মন,হবে,হবে,থাকে,হবে,বাইরে,থাকে,UNK,তো,UNK,হবে,তো,UNK,কিছু,নেই,ছাড়া,তো,UNK,মাথা,UNK,নিচু,ছাড়া,নিচু,মাথা,নেই,বকুল,ফেলল,করে,মাথা,তার,করে,চোখে,চোখে,আসছে,তার,পানি,চোখে,তার,তার,বাবা,আরো,দেখে,UNK,আসছে,রেগে,দেখে,বাবা,যাবেন,আরো,আজেবাজে,UNK,কথা,কথা,রেগে,যাবেন,বলবেন,কথা,একবার,কথা,একবার,কথা,এমন,বলবেন,একবার,সব,একবার,কথা,রেগে,এমন,কথা,গেলে,মরে,এমন,কথা,মরে,সব,ইচ্ছা,যেতে,যে,বলেন,UNK,করে,যেতে,UNK,UNK,করে,করে,ইচ্ছা,মুখ,UNK,UNK,UNK,UNK,UNK,তো,UNK,কোনো,মুখ,মুখ,তবু,UNK,UNK,UNK,দেখি,একশ,তো,তো,একশ,একশ,কোনো,লাগে,শুধু,শুধু,UNK,UNK,একশ,মুনা,টাকার,শুধু,লাগে,কড়া,UNK,মুনা,UNK,মুনা,সাহেব,মুনা,কড়া,গলায়,UNK,শওকত,কড়া,গলায়,সাহেব,শওকত,UNK,সাহেব,উঁচু,UNK,UNK,UNK,মুখে,বাবু,ঘরে,ঘরে,বাবু,সে,ঢুকল,ঢুকল,UNK,মুখে,সে,UNK,মুখে,ক্লাস,সে,ঢুকল,সন্ধ্যায়,ক্লাস,তার,মাথা,ক্লাস,রোজ,তার,UNK,বলেই,ধরে,বলেই,বলেই,সন্ধ্যায়,করে,ঘর,বলেই,অন্ধকার,শুয়ে,করে,থাকে,ঘর,অন্ধকার,করে,করে,অন্ধকার,করে,বাবুকে,দেখেই,থাকে,রেগে,সাহেব,সাহেব,কানে,উঠলেন,বাবুকে,UNK,বাবুকে,শুনতে,দেখেই,বাবু,কানে,বাবু,না,কানে,UNK,UNK,ভয়ে,বাবু,UNK,না,বকুলের,ভয়ে,ভয়ে,ভয়ে,তাকাল,শওকত,বকুলের,সাহেব,তাকাল,দিয়ে,উঠলেন,উঠলেন,দিকে,দরজা,UNK,UNK,দরজা,দিয়ে,UNK,দিয়ে,UNK,না,দরজা,দরজা,UNK,দরজা,না,দরজা,খুলল,না,দরজা,খুলল,বাবু,মুনার,দরজা,মুনার,সাহেব,শওকত,UNK,শওকত,UNK,মুনার,না,কোনো,UNK,মুনার,না,রকম,UNK,কারণ,UNK,UNK,বকুলের,কোনো,রকম,UNK,UNK,করে,UNK,UNK,কারণ,করে,UNK,UNK,UNK,ব্যাপারটা,করে,UNK,করে,করে,চড়,UNK,একটা,ব্যাপারটা,UNK,UNK,বকুলের,মুখ,UNK,লাল,UNK,মুখ,উঠল,হয়ে,মুখ,UNK,মুখ,UNK,লাল,মাথা,অনেকখানি,UNK,হয়ে,উঠল,UNK,UNK,তার,তার,মাথা,UNK,কী,অনেকখানি,সে,তার,সে,সে,তার,চেষ্টা,তার,করল,কী,করল,কী,সব,UNK,UNK,চেষ্টা,চোখ,করল,চোখ,করল,UNK,সব,পড়ছে,UNK,কিছুই,UNK,চোখ,পড়ছে,থেকে,দেখা,UNK,দেখা,পড়ছে,UNK,শওকত,সাহেব,শওকত,দেখা,স্বরে,দেখা,স্বরে,UNK,শওকত,না,UNK,UNK,করিস,সাহেব,না,UNK,UNK,করিস,বকুল,না,UNK,মাথা,না,UNK,না,না,বকুল,মাথা,হালকা,তার,তুলল,মাথা,তুলল,UNK,ছোট্ট,না,হালকা,ছোট্ট,লাগল,UNK,লাগল,হালকা,শরীর,মুনা,উঠতে,UNK,স্বরে,শান ...

# %%
# এই ভেরিয়েবলে আমরা আমাদের এম্বিডিং কে স্টোর করে রাখবে
embedding = tf.Variable(tf.random.normal([VOCABULARY_SIZE, EMBEDDING_SIZE]))

# এই ভেরিয়েবল গুলো NCE loss হিসাব করার সময় ব্যাবহার হবে 
nce_weights = tf.Variable(tf.random.normal([VOCABULARY_SIZE, EMBEDDING_SIZE]))
nce_biases = tf.Variable(tf.zeros([VOCABULARY_SIZE]))

# %%
def get_embedding(word):
    # প্রতিটা ওয়ার্ড এর বিপরীতে 'embedding' ভেরিয়েবলে যে embedding স্টোর করা আছে সেটা বের করা 
    x_embed = tf.nn.embedding_lookup(embedding, word)
    return x_embed

def nce_loss(x_embed, y):
    # একটা ব্যাচ ডাটার বিপরীতে NCE loss হিসাব করা
    y = tf.cast(y, tf.int64)
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=y,
            inputs=x_embed,
            num_sampled=NUM_SAMPLED, # number of negative sample used
            num_classes=VOCABULARY_SIZE
        )
    )
    return loss


def cosing_similarity(x_embed):
    # ইনপুট এম্বেডিং ভেক্টরের সাথে প্রতিটা এম্বেডিং ভেক্টরের cosine similarity বের করা
    x_embed = tf.cast(x_embed, tf.float32)
    x_embed_norm = x_embed / tf.sqrt(tf.reduce_sum(tf.square(x_embed)))
    embedding_norm = embedding / tf.sqrt(
        tf.reduce_sum(tf.square(embedding), 1, keepdims=True), tf.float32
    )
    cosine_sim_op = tf.matmul(x_embed_norm, embedding_norm, transpose_b=True)
    return cosine_sim_op

# আমরা SGD optimizer ব্যাবহার করব 
optimizer = tf.optimizers.SGD(LEARNING_RATE)

# %%
x_test = np.array([word2id[w] for w in EVAL_WORDS])

start_time = time.time()
for step in range(1, NUM_STEPS+1):
    # ট্রেনিং এর জন্য ডাটা নেই 
    target_x, context_y = next_batch(BATCH_SIZE, NUM_SKIPS, SKIP_WINDOW)
    
    with tf.GradientTape() as tape:
        # টার্গেট শব্দগুলোর বর্তমান এম্বেডিং বের করি
        emb = get_embedding(target_x)
        # এম্বিডিং এবং কন্টেক্সট থেকে লস হিসাব করি । 
        loss = nce_loss(emb, context_y)
    # loss এর সাপেক্ষে embedding, nce_weights, nce_biases ভেরিয়েবল গুলোর গ্রাডিয়েন্ট হিসাব করা 
    gradients = tape.gradient(loss, [embedding, nce_weights, nce_biases])
    # এই গ্রাডিয়েন্ট ধরে আমরা embedding, nce_weights, nce_biases ভেরিয়েবল গুলোর ভেলু আপডেট
    # করি 
    optimizer.apply_gradients(zip(gradients, [embedding, nce_weights, nce_biases]))
    
    # নিদিষ্ট স্টেপ পর পর আমরা লস দেখব 
    if step % DISPLAY_STEPS == 0 or step == 1:
        temp_emb = get_embedding(batch_x)
        loss = nce_loss(temp_emb, batch_y)
        print("Step: {} loss: {:.4f} time: {}".format(
            step, loss, time.time()-start_time)
        )
        start_time = time.time()
        
    # আমাদের সেট করা কিছু টেস্ট শব্দ দিয়ে আমরা টেস্ট করে দেখব আমাদের মডেল কেমন শিখতেছে
    if step % EVAL_STEPS == 0 or step == 1:
        print("Testing...")
        similarity = cosing_similarity(get_embedding(x_test)).numpy()
        for i in range(len(EVAL_WORDS)):
            top_k = 8  # আমরা কতগুলো নেয়ারেস্ট শব্দ দেখতে চাই সেটা সেট করে দিলাম 
            nearest = (-similarity[i, :]).argsort()[1:top_k+1]
            log_str = "'{}' এর কাছের শব্দ গুলো: ".format(EVAL_WORDS[i])
            for k in range(top_k):
                log_str = "{} {},".format(log_str, id2word[nearest[k]])
            print(log_str)
# Out:
# Step: 1 loss: 115.20759582519531 time: 0.0004235943158467611
# Testing...
# 'মুনা' এর কাছের শব্দ গুলো:  না, UNK, করে, হয়, তার, বলল, আছে, আমার,
# 'বকুল' এর কাছের শব্দ গুলো:  করে, তো, তুমি, হয়, কিছু, না, শুয়ে, UNK,
# 'বাকের' এর কাছের শব্দ গুলো:  সে, না, কিছু, UNK, তো, কথা, এই, মুনা,
# Step: 10000 loss: 9.455401420593262 time: 2.2726904074350993
# Step: 20000 loss: 7.710119724273682 time: 2.2709779103597003
# Step: 30000 loss: 7.070896148681641 time: 2.2607158144315083
# Step: 40000 loss: 6.505194664001465 time: 2.2212836742401123
# Step: 50000 loss: 6.173004150390625 time: 2.214940134684245
# Step: 60000 loss: 5.946339130401611 time: 2.2243704438209533
# Step: 70000 loss: 5.727808952331543 time: 2.221015910307566
# Step: 80000 loss: 5.547652244567871 time: 2.1990910172462463
# Step: 90000 loss: 5.408536434173584 time: 2.1639158805211385
# Step: 100000 loss: 5.279882431030273 time: 2.123226515452067
# Step: 110000 loss: 5.184957027435303 time: 2.106153655052185
# Step: 120000 loss: 5.0996479988098145 time: 2.108219035466512
# Step: 130000 loss: 5.021121025085449 time: 2.108826458454132
# Step: 140000 loss: 5.004368782043457 time: 2.113181738058726
# Step: 150000 loss: 4.885924816131592 time: 2.1052868803342184
# Step: 160000 loss: 4.8462138175964355 time: 2.1030974825223288
# Step: 170000 loss: 4.791365623474121 time: 2.107759968439738
# Step: 180000 loss: 4.754326820373535 time: 2.1050782958666483
# Step: 190000 loss: 4.712499618530273 time: 2.107535886764526
# Step: 200000 loss: 4.659974098205566 time: 2.097264516353607
# Testing...
# 'মুনা' এর কাছের শব্দ গুলো:  বকুল, না, বাকের, করে, বলল, সে, কেন, UNK,
# 'বকুল' এর কাছের শব্দ গুলো:  মুনা, না, বলল, কেন, করে, UNK, বাকের, সে,
# 'বাকের' এর কাছের শব্দ গুলো:  মুনা, বকুল, না, করে, UNK, দিয়ে, সে, কথা,
# Step: 210000 loss: 4.643957614898682 time: 2.0891512989997865
# Step: 220000 loss: 4.634835720062256 time: 2.094070633252462
# Step: 230000 loss: 4.586221694946289 time: 2.08938779036204
# Step: 240000 loss: 4.5688323974609375 time: 2.095710357030233
# Step: 250000 loss: 4.526012420654297 time: 2.115777929623922
# Step: 260000 loss: 4.522487640380859 time: 2.1258484443028767
# Step: 270000 loss: 4.494353771209717 time: 2.142400773366292
# Step: 280000 loss: 4.480099678039551 time: 2.1417412400245666
# Step: 290000 loss: 4.4421916007995605 time: 2.16306414604187
# Step: 300000 loss: 4.403162479400635 time: 2.1549124240875246
# Step: 310000 loss: 4.408456802368164 time: 2.133093810081482
# Step: 320000 loss: 4.425971031188965 time: 2.1303428689638775
# Step: 330000 loss: 4.391371726989746 time: 2.132253058751424
# Step: 340000 loss: 4.366987228393555 time: 2.1308353583017987
# Step: 350000 loss: 4.335179328918457 time: 2.116783610979716
# Step: 360000 loss: 4.332767009735107 time: 2.122726575533549
# Step: 370000 loss: 4.347087383270264 time: 2.1157851616541543
# Step: 380000 loss: 4.347710609436035 time: 2.1155774076779683
# Step: 390000 loss: 4.327152729034424 time: 2.1209163745244344
# Step: 400000 loss: 4.28278923034668 time: 2.1125175317128497
# Testing...
# 'মুনা' এর কাছের শব্দ গুলো:  বকুল, মামুন, না, বাকের, বলল, করে, সে, কেন,
# 'বকুল' এর কাছের শব্দ গুলো:  মুনা, কেন, না, বলল, আমি, বাবু, বাকের, করে,
# 'বাকের' এর কাছের শব্দ গুলো:  মুনা, বকুল, মামুন, UNK, দিয়ে, ভাই, না, করে,

# %%
# Save only vector to a tsv file
# tensorflow projector only accepts this format of data
with open('kothou_keu_nei_vector.tsv', 'w') as fp:
    for i in range(VOCABULARY_SIZE):
        # i তম শব্দের জন্য এম্বেডিং
        embed = embedding[i, :]
        # convert embedding to numpy and save it to a file
        fp.write('{}\n'.format('\t'.join(map(str, embed.numpy()))))

# Save all vocabulary to a file
with open('kothou_keu_nei_metadata.tsv', 'w') as fp:
    for i in range(VOCABULARY_SIZE):
        # take word from word id
        word = id2word[i]
        # write it to a file
        fp.write('{}\n'.format(word))

# %% [markdown]
# ## Visualize Learned Embeddings:
#
# Load vector and metadata tsv to projector
# - [https://projector.tensorflow.org/](https://projector.tensorflow.org/)
# - You can also user tensorboard `projector` tab

# %% [markdown]
# ## Resoruces
# - [Efficient Estimation of Word Representations inVector Space](https://arxiv.org/pdf/1301.3781.pdf)
# - [Skipgram with examples](https://www.tensorflow.org/tutorials/text/word2vec#skip-gram_and_negative_sampling)
# - [Word2Vec Tensorflow 2x with low level api](https://github.com/aymericdamien/TensorFlow-Examples/blob/master/tensorflow_v2/notebooks/2_BasicModels/word2vec.ipynb)
# - [Word2Vec using Embedding Layer Tensorflow 2x](https://petamind.com/word2vec-with-tensorflow-2-0-a-simple-cbow-implementation/)
# - [Word2Vec](https://www.tensorflow.org/tutorials/text/word2vec)
# - [Word Embeddings](https://www.tensorflow.org/tutorials/text/word_embeddings)
# - [skipgram function defination](https://keras.rstudio.com/reference/skipgrams.html)
